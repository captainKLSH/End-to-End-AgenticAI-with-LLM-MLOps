# %%
print("AL")
# Out:
# AL

# %%
from dotenv import load_dotenv

# %%
from langchain_groq import ChatGroq

# %%
llm=ChatGroq(model="deepseek-r1-distill-llama-70b")
# Out:
# ---------------------------------------------------------------------------
# GroqError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 llm=ChatGroq(model="deepseek-r1-distill-llama-70b")
#
# File ~/Documents/Pros/DL/End-to-End-AgenticAI-with-LLM-MLOps/env/lib/python3.12/site-packages/langchain_core/load/serializable.py:116, in Serializable.__init__(self, *args, **kwargs)
#     114 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     115     """"""  # noqa: D419  # Intentional blank docstring
# --> 116     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~/Documents/Pros/DL/End-to-End-AgenticAI-with-LLM-MLOps/env/lib/python3.12/site-packages/langchain_groq/chat_models.py:489, in ChatGroq.validate_environment(self)
#     487 sync_specific: dict[str, Any] = {"http_client": self.http_client}
#     488 if not self.client:
# --> 489     self.client = groq.Groq(
#     490         **client_params, **sync_specific
#     491     ).chat.completions
#     492 if not self.async_client:
#     493     async_specific: dict[str, Any] = {"http_client": self.http_async_client}
#
# File ~/Documents/Pros/DL/End-to-End-AgenticAI-with-LLM-MLOps/env/lib/python3.12/site-packages/groq/_client.py:79, in Groq.__init__(self, api_key, base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#      77     api_key = os.environ.get("GROQ_API_KEY")
#      78 if api_key is None:
# ---> 79     raise GroqError(
#      80         "The api_key client option must be set either by passing api_key to the client or by setting the GROQ_API_KEY environment variable"
#      81     )
#      82 self.api_key = api_key
#      84 if base_url is None:
#
# GroqError: The api_key client option must be set either by passing api_key to the client or by setting the GROQ_API_KEY environment variable

# %%
llm.invoke("hi")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 llm.invoke("hi")
#
# NameError: name 'llm' is not defined

# %%
from langchain.tools import tool

# %%
@tool
def multiply(a: int, b: int) -> int:
    """
    Multiply two integers.

    Args:
        a (int): The first integer.
        b (int): The second integer.

    Returns:
        int: The product of a and b.
    """
    return a * b

# %%
multiply
# Out:
# StructuredTool(name='multiply', description='Multiply two integers.\n\nArgs:\n    a (int): The first integer.\n    b (int): The second integer.\n\nReturns:\n    int: The product of a and b.', args_schema=<class 'langchain_core.utils.pydantic.multiply'>, func=<function multiply at 0x11c5c9440>)

# %%
from langchain_core.tools import StructuredTool

# %%
class WeatherInput(BaseModel):
    city: str
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 class WeatherInput(BaseModel):
#       2     city: str
#
# NameError: name 'BaseModel' is not defined

# %%
def get_weather(city: str) -> str:
    """
    Get the weather for a given city.

    Args:
        city (str): The name of the city.

    Returns:
        str: A string describing the weather in the city.
    """
    return f"The weather in {city} is sunny."

# %%
weather_tool = StructuredTool.from_function(
    func=get_weather,
    name="get_weather",
    description="Fetches real-time weather data for a city",
    args_schema=WeatherInput,  
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 5
#       1 weather_tool = StructuredTool.from_function(
#       2     func=get_weather,
#       3     name="get_weather",
#       4     description="Fetches real-time weather data for a city",
# ----> 5     args_schema=WeatherInput,
#       6 )
#
# NameError: name 'WeatherInput' is not defined

# %%
class WeatherInput(BaseModel):
    city: str = Field(..., description="City name")
    units: str = Field("metric", description="metric or imperial")

class GetWeatherTool(StructuredTool):
    name: ClassVar[str] = "get_weather"           
    description: ClassVar[str] = (
        "Fetches weather data for a city"
    )
    args_schema: ClassVar[Type[BaseModel]] = WeatherInput

    def _run(self, city: str, units: str = "metric") -> str:
        return get_weather(city, units)
